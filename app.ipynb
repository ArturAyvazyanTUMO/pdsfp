# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting magic
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import warnings
warnings.simplefilter('ignore', FutureWarning)
warnings.simplefilter('ignore', UserWarning)
from matplotlib import patches
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %%
armenia=Table.read_table("tables/armenia.csv")
armenia.show()
luxemburg=Table.read_table("tables/luxemburg.csv")
jordan=Table.read_table("tables/jordan.csv")
israel=Table.read_table("tables/israel.csv")
georgia=Table.read_table("tables/georgia.csv")
liechtenstein=Table.read_table("tables/liechtenstein.csv")
slovenia=Table.read_table("tables/slovenia.csv")
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>Year</th> <th>Population</th> <th>Yearly %
# Change</th> <th>Yearly
# Change</th> <th>Migrants (net)</th> <th>Median Age</th> <th>Fertility Rate</th> <th>Density (P/Km²)</th> <th>Urban
# Pop %</th> <th>Urban Population</th> <th>Country's Share of
# World Pop</th> <th>World Population</th> <th>Armenia
# Global Rank</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>2018</td> <td>2,934,152 </td> <td>0.13 %          </td> <td>3,702        </td> <td>-4,998        </td> <td>34.3      </td> <td>1.64          </td> <td>103            </td> <td>63.7 %     </td> <td>1,867,160       </td> <td>0.04 %                      </td> <td>7,632,819,325   </td> <td>139                </td>
#         </tr>
#         <tr>
#             <td>2017</td> <td>2,930,450 </td> <td>0.19 %          </td> <td>5,634        </td> <td>-4,998        </td> <td>34.3      </td> <td>1.64          </td> <td>103            </td> <td>63.8 %     </td> <td>1,869,644       </td> <td>0.04 %                      </td> <td>7,550,262,101   </td> <td>138                </td>
#         </tr>
#         <tr>
#             <td>2016</td> <td>2,924,816 </td> <td>0.27 %          </td> <td>7,866        </td> <td>-4,998        </td> <td>34.3      </td> <td>1.64          </td> <td>103            </td> <td>64.0 %     </td> <td>1,871,933       </td> <td>0.04 %                      </td> <td>7,466,964,280   </td> <td>139                </td>
#         </tr>
#         <tr>
#             <td>2015</td> <td>2,916,950 </td> <td>0.27 %          </td> <td>7,928        </td> <td>-6,107        </td> <td>33.9      </td> <td>1.65          </td> <td>102            </td> <td>64.2 %     </td> <td>1,873,591       </td> <td>0.04 %                      </td> <td>7,383,008,820   </td> <td>140                </td>
#         </tr>
#         <tr>
#             <td>2010</td> <td>2,877,311 </td> <td>-0.71 %         </td> <td>-20,790      </td> <td>-36,672       </td> <td>32.9      </td> <td>1.72          </td> <td>101            </td> <td>65.5 %     </td> <td>1,884,192       </td> <td>0.04 %                      </td> <td>6,958,169,159   </td> <td>139                </td>
#         </tr>
#         <tr>
#         </tr>
#         <tr>
#             <td>1960</td> <td>1,874,120 </td> <td>3.69 %          </td> <td>62,123       </td> <td>11,986        </td> <td>22.4      </td> <td>4.9           </td> <td>66             </td> <td>51.1 %     </td> <td>957,511         </td> <td>0.06 %                      </td> <td>3,033,212,527   </td> <td>121                </td>
#         </tr>
#         <tr>
#             <td>1955</td> <td>1,563,505 </td> <td>2.93 %          </td> <td>41,999       </td> <td>9,973         </td> <td>22.7      </td> <td>4.49          </td> <td>55             </td> <td>46.0 %     </td> <td>718,455         </td> <td>0.06 %                      </td> <td>2,772,242,535   </td> <td>121                </td>
#         </tr>
#     </tbody>
# </table>

# %%
def removeComma(clm):
    return np.char.replace(clm,",","")

# %%
x=armenia.column(0)
y=removeComma(armenia.column(1))

line1, = plt.plot(x, y, label="Armenia's population")
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

x=luxemburg.column(0)
y=removeComma(luxemburg.column(1))

line2 = plt.plot(x, y, label="Luxemburg's population")

x=jordan.column(0)
y=removeComma(jordan.column(1))

line4 = plt.plot(x, y,color='#ff0894', label="Jordan's population")

x=israel.column(0)
y=removeComma(israel.column(1))

line5 = plt.plot(x, y, label="Israel's population")

x=georgia.column(0)
y=removeComma(georgia.column(1))

line6 = plt.plot(x, y, label="Georgia's population")

x=slovenia.column(0)
y=removeComma(slovenia.column(1))

line10 = plt.plot(x, y,color="aqua", label="Slovenia's population")

plt.suptitle('Population of countries which are similar to Armenia', fontsize=16)
plt.rcParams['figure.figsize']=[10,5]
plt.legend(loc='lower',title="Population Comparing")
plt.show()

# %%
def part(clm):
    num = []
    for i in range(clm.num_rows):
            num.append(str(float(int(removeComma(clm.column(1)).item(i))/int(removeComma(clm.column(11)).item(i)))*100))
    x  = np.array(num)
    return x

# %%
y=armenia.column(0)

line1, = plt.plot(part(armenia), y, label="Armenia's population")
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

line2 = plt.plot(part(luxemburg), y, label="Luxemburg's population")

line4 = plt.plot(part(jordan), y,color='#ff0894', label="Jordan's population")

line5 = plt.plot(part(israel), y, label="Israel's population")

line6 = plt.plot(part(georgia), y, label="Georgia's population")

line7 = plt.plot(part(slovenia), y,color="aqua", label="Slovenia's population")

plt.suptitle('Population of countries which are similar to Armenia', fontsize=16)
plt.rcParams['figure.figsize']=[10,5]
plt.legend(loc='lower',title="Population Comparing")
plt.show()
